# %% [markdown]
# ## Import the data and briefly explore it again

# %%
#from google.colab import drive
#drive.mount('/content/drive', force_remount=True)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

import random
import math

# %%
url = "https://raw.githubusercontent.com/desstaw/PrivacyPreservingTechniques/main/datasets/adult_v1_gen.csv"
df = pd.read_csv(url)

# %%
df.columns
# Out:
# Index(['ID', 'sex', 'L7_age', 'L2_race', 'L3_marital_status', 'L5_education',
#        'L3_native_country', 'L3_workclass', 'L3_occupation', 'salary-class',
#        'L1_age', 'L2_age', 'L3_age', 'L4_age', 'L5_age', 'L6_age',
#        'L1_education', 'L2_education', 'L3_education', 'L4_education',
#        'L1_occupation', 'L2_occupation', 'L1_marital_status',
#        'L2_marital_status', 'L1_workclass', 'L2_workclass',
#        'L1_native_country', 'L2_native_country', 'L1_race'],
#       dtype='object')

# %%
# Define the new order of column names
new_order = ['sex', 'L1_age', 'L2_age', 'L3_age', 'L4_age', 'L5_age', 'L6_age', 'L7_age',
             'L1_education', 'L2_education', 'L3_education', 'L4_education', 'L5_education',
             'L1_occupation', 'L2_occupation', 'L3_occupation',
             'L1_workclass', 'L2_workclass', 'L3_workclass',
             'L1_marital_status', 'L2_marital_status', 'L3_marital_status',
             'L1_native_country', 'L2_native_country', 'L3_native_country',
             'L1_race', 'L2_race', 'salary-class']

# Reorder the columns
df = df[new_order]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30162 entries, 0 to 30161
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sex                30162 non-null  object
#  1   L1_age             30162 non-null  object
#  2   L2_age             30162 non-null  object
#  3   L3_age             30162 non-null  object
#  4   L4_age             30162 non-null  object
#  5   L5_age             30162 non-null  object
#  6   L6_age             30162 non-null  object
#  7   L7_age             30162 non-null  float64
#  8   L1_education       30162 non-null  object
#  9   L2_education       30162 non-null  object
#  10  L3_education       30162 non-null  object
#  11  L4_education       30162 non-null  object
#  12  L5_education       30162 non-null  object
#  13  L1_occupation      30162 non-null  object
#  14  L2_occupation      30162 non-null  object
#  15  L3_occupation      30162 non-null  object
#  16  L1_workclass       30162 non-null  object
#  17  L2_workclass       30162 non-null  object
#  18  L3_workclass       30162 non-null  object
#  19  L1_marital_status  30162 non-null  object
#  20  L2_marital_status  30162 non-null  object
#  21  L3_marital_status  30162 non-null  object
#  22  L1_native_country  30162 non-null  object
#  23  L2_native_country  30031 non-null  object
#  24  L3_native_country  30162 non-null  object
#  25  L1_race            30162 non-null  object
#  26  L2_race            30162 non-null  object
#  27  salary-class       30162 non-null  object
# dtypes: float64(1), object(27)
# memory usage: 6.4+ MB

# %% [markdown]
# ## Necessary pre-processing for CatBoost

# %%
df ['sex'] = df ['sex'].astype(str)
df ['salary-class'] = df ['salary-class'].astype(str)


df ['L1_age'] = df ['L1_age'].astype(str)
df ['L2_age'] = df ['L2_age'].astype(str)
df ['L3_age'] = df ['L3_age'].astype(str)
df ['L3_age'] = df ['L3_age'].astype(str)
df ['L4_age'] = df ['L4_age'].astype(str)
df ['L5_age'] = df ['L5_age'].astype(str)
df ['L6_age'] = df ['L6_age'].astype(str)
df ['L7_age'] = df ['L7_age'].astype(str)

df ['L1_education'] = df ['L1_education'].astype(str)
df ['L2_education'] = df ['L2_education'].astype(str)
df ['L3_education'] = df ['L3_education'].astype(str)
df ['L4_education'] = df ['L4_education'].astype(str)
df ['L5_education'] = df ['L5_education'].astype(str)

df ['L1_occupation'] = df ['L1_occupation'].astype(str)
df ['L2_occupation'] = df ['L2_occupation'].astype(str)
df ['L3_occupation'] = df ['L3_occupation'].astype(str)

df ['L1_marital_status'] = df ['L1_marital_status'].astype(str)
df ['L2_marital_status'] = df ['L2_marital_status'].astype(str)
df ['L3_marital_status'] = df ['L3_marital_status'].astype(str)

df ['L1_workclass'] = df ['L1_workclass'].astype(str)
df ['L3_workclass'] = df ['L2_workclass'].astype(str)
df ['L3_workclass'] = df ['L3_workclass'].astype(str)

df ['L1_native_country'] = df ['L1_native_country'].astype(str)
df ['L2_native_country'] = df ['L2_native_country'].astype(str)
df ['L3_native_country'] = df ['L3_native_country'].astype(str)

df ['L1_race'] = df ['L1_race'].astype(str)
df ['L2_race'] = df ['L2_race'].astype(str)

# %% [markdown]
# Visual distribution of categorical attributes

# %%
'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the list of categorical columns to visualize
#cat_cols = ['sex', 'L7_age', 'L5_education', 'L3_occupation', 'L3_marital_status', 'L3_workclass', 'L3_native_country', 'L2_race', 'salary-class']
cat_cols = df.select_dtypes(include=['object']).columns

# Determine the number of subplots based on the number of categorical columns
num_subplots = len(cat_cols)

# Set up the subplots
fig, axes = plt.subplots(num_subplots, 1, figsize=(10, 4 * num_subplots))

# Loop through each categorical column and create a countplot in the corresponding subplot
for i, column in enumerate(cat_cols):
    sns.countplot(data=df, x=column, ax=axes[i])
    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=30)  # Rotate x-axis labels for better readability
    axes[i].set_title(f'Distribution of {column}')
    axes[i].set_xlabel(None)  # Remove x-axis label for better layout

# Adjust the layout
plt.tight_layout()

# Show the plots
plt.show()
'''
# Out:
# "\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\n\n# Define the list of categorical columns to visualize\n#cat_cols = ['sex', 'L7_age', 'L5_education', 'L3_occupation', 'L3_marital_status', 'L3_workclass', 'L3_native_country', 'L2_race', 'salary-class']\ncat_cols = df.select_dtypes(include=['object']).columns\n\n# Determine the number of subplots based on the number of categorical columns\nnum_subplots = len(cat_cols)\n\n# Set up the subplots\nfig, axes = plt.subplots(num_subplots, 1, figsize=(10, 4 * num_subplots))\n\n# Loop through each categorical column and create a countplot in the corresponding subplot\nfor i, column in enumerate(cat_cols):\n    sns.countplot(data=df, x=column, ax=axes[i])\n    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=30)  # Rotate x-axis labels for better readability\n    axes[i].set_title(f'Distribution of {column}')\n    axes[i].set_xlabel(None)  # Remove x-axis label for better layout\n\n# Adjust the layout\nplt.tight_layout()\n\n# Show the plots\nplt.show()\n"

# %%
#df = df.drop('ID', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30162 entries, 0 to 30161
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sex                30162 non-null  object
#  1   L1_age             30162 non-null  object
#  2   L2_age             30162 non-null  object
#  3   L3_age             30162 non-null  object
#  4   L4_age             30162 non-null  object
#  5   L5_age             30162 non-null  object
#  6   L6_age             30162 non-null  object
#  7   L7_age             30162 non-null  object
#  8   L1_education       30162 non-null  object
#  9   L2_education       30162 non-null  object
#  10  L3_education       30162 non-null  object
#  11  L4_education       30162 non-null  object
#  12  L5_education       30162 non-null  object
#  13  L1_occupation      30162 non-null  object
#  14  L2_occupation      30162 non-null  object
#  15  L3_occupation      30162 non-null  object
#  16  L1_workclass       30162 non-null  object
#  17  L2_workclass       30162 non-null  object
#  18  L3_workclass       30162 non-null  object
#  19  L1_marital_status  30162 non-null  object
#  20  L2_marital_status  30162 non-null  object
#  21  L3_marital_status  30162 non-null  object
#  22  L1_native_country  30162 non-null  object
#  23  L2_native_country  30162 non-null  object
#  24  L3_native_country  30162 non-null  object
#  25  L1_race            30162 non-null  object
#  26  L2_race            30162 non-null  object
#  27  salary-class       30162 non-null  object
# dtypes: object(28)
# memory usage: 6.4+ MB

# %%
#Since the catboost model cannot read columns with interval values which are originally intended to be categories in the form of interval strings
def generate_interval_mappings(df, interval_columns):
    interval_mapping = {}

    for column in interval_columns:
        unique_intervals = df[column].unique()
        for interval in unique_intervals:
            if isinstance(interval, tuple):  # Check if the interval is a tuple
                mapping_key = f"{column}_{interval[0]}_{interval[1]}"
                interval_mapping[interval] = mapping_key
                print('interval mapping', interval_mapping)

    return interval_mapping

# List of columns with interval values
interval_columns = df[['L7_age', 'L2_race', 'L3_marital_status', 'L5_education',
       'L3_native_country', 'L3_workclass', 'L3_occupation', 'salary-class',
       'L1_age', 'L2_age', 'L3_age', 'L4_age', 'L5_age', 'L6_age',
       'L1_education', 'L2_education', 'L3_education', 'L4_education',
       'L1_occupation', 'L2_occupation', 'L1_marital_status',
       'L2_marital_status', 'L1_workclass', 'L2_workclass',
       'L1_native_country', 'L2_native_country', 'L1_race']]

# Generate interval mappings
interval_mapping = generate_interval_mappings(df, interval_columns)

# Apply the interval mapping to create new categorical columns
for column, mapping in interval_mapping.items():
    df[mapping] = df[column].apply(lambda interval: mapping if interval in interval_mapping else None)

# Drop the original columns with intervals
for column in interval_mapping.keys():
    df.drop(column, axis=1, inplace=True)


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30162 entries, 0 to 30161
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sex                30162 non-null  object
#  1   L1_age             30162 non-null  object
#  2   L2_age             30162 non-null  object
#  3   L3_age             30162 non-null  object
#  4   L4_age             30162 non-null  object
#  5   L5_age             30162 non-null  object
#  6   L6_age             30162 non-null  object
#  7   L7_age             30162 non-null  object
#  8   L1_education       30162 non-null  object
#  9   L2_education       30162 non-null  object
#  10  L3_education       30162 non-null  object
#  11  L4_education       30162 non-null  object
#  12  L5_education       30162 non-null  object
#  13  L1_occupation      30162 non-null  object
#  14  L2_occupation      30162 non-null  object
#  15  L3_occupation      30162 non-null  object
#  16  L1_workclass       30162 non-null  object
#  17  L2_workclass       30162 non-null  object
#  18  L3_workclass       30162 non-null  object
#  19  L1_marital_status  30162 non-null  object
#  20  L2_marital_status  30162 non-null  object
#  21  L3_marital_status  30162 non-null  object
#  22  L1_native_country  30162 non-null  object
#  23  L2_native_country  30162 non-null  object
#  24  L3_native_country  30162 non-null  object
#  25  L1_race            30162 non-null  object
#  26  L2_race            30162 non-null  object
#  27  salary-class       30162 non-null  object
# dtypes: object(28)
# memory usage: 6.4+ MB

# %% [markdown]
# ## K-anonymity and Simulated Annealing

# %% [markdown]
# ### Quasi identiifers are formed as `'key': ['set1', 'set2',...]`. The aim to swap from each corresponding set later and not randomly from the whole columns.

# %%
# Define the QI columns and their possible values
quasi_identifiers = {
    'sex': ['sex'],
    'age': ['L1_age', 'L2_age', 'L3_age', 'L4_age', 'L5_age', 'L6_age', 'L7_age'],
    'race': [ 'L1_race', 'L2_race'],
    'education': ['L1_education', 'L2_education', 'L3_education', 'L4_education', 'L5_education'],
    'occupation': [ 'L1_occupation', 'L2_occupation', 'L3_occupation'],
    'workclass':['L1_workclass', 'L2_workclass', 'L3_workclass'],
    'marital_status': ['L1_marital_status', 'L2_marital_status', 'L3_marital_status'],
    'native_country': ['L1_native_country', 'L2_native_country', 'L3_native_country']
}




# Define the initial solution randomly
initial_solution = [
    random.choice(quasi_identifiers['sex']),
    random.choice(quasi_identifiers['age']),
    random.choice(quasi_identifiers['race']),
    random.choice(quasi_identifiers['education']),
    random.choice(quasi_identifiers['occupation']),
    random.choice(quasi_identifiers['workclass']),
    random.choice(quasi_identifiers['marital_status']),
    random.choice(quasi_identifiers['native_country'])


]

initial_solution = ['sex', 'L6_age', 'L2_race', 'L3_education', 'L3_occupation', 'L3_workclass', 'L2_marital_status', 'L1_native_country']
print(initial_solution)
# Out:
# ['sex', 'L6_age', 'L2_race', 'L3_education', 'L3_occupation', 'L3_workclass', 'L2_marital_status', 'L1_native_country']

# %% [markdown]
# ###Simulated annealing parameters

# %%
# temperature and cooling rate for SA
initial_temperature = 1000 #100
cooling_rate = 0.01
min_temperature = 0.001

# number of iterations at each temperature level
num_iterations = 60 #60 #200

# maximum number of iterations without improvement
max_iterations_without_improvement = 8

total_iterations = 300 #100   # Initialize the total number of iterations

# Calculate the number of temperature levels based on total_iterations and num_iterations
num_temperature_levels = total_iterations // num_iterations

# Use num_temperature_levels to set the range of the temperature loop
current_temperature = initial_temperature

# Tried to implement adaptive cooling schedule but got confused more
'''
while current_temperature > min_temperature:
    total_iterations += num_iterations
    current_temperature *= cooling_rate

print("Max. Number of Iterations:", total_iterations)
'''
# Adjust the current temperature using the cooling rate
for _ in range(num_temperature_levels):
    current_temperature *= cooling_rate

# %% [markdown]
# ### Classification model

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.2-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.2

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score

def calculate_classification_accuracy(selected_columns, df, k):

    random_seed = 23 #23  # You can use any integer value as the seed
    np.random.seed(random_seed)

    # Prepare the feature matrix (X) and target variable (y)
    X = df[selected_columns]
    y = df['salary-class']

    # Print the number of rows in X and y
    print('X columns:', X.columns)
    print("Number of rows in X:", len(X))
    print("Number of rows in y:", len(y))

    # Convert categorical features to strings
    categorical_features_indices = X.select_dtypes(include=['object']).columns

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed)

    # Initialize the CatBoostClassifier
    catboost_model = CatBoostClassifier(iterations=50, depth=10, learning_rate=0.1, loss_function='Logloss', cat_features=list(categorical_features_indices))

    # Train the model on the training data
    catboost_model.fit(X_train, y_train, cat_features=list(categorical_features_indices))

    # Predict on the testing data
    y_pred = catboost_model.predict(X_test)

    # Calculate and return the classification accuracy
    accuracy = accuracy_score(y_test, y_pred)

    # Convert labels to binary values (0 and 1)
    y_test_binary = np.where(y_test == '<=50K', 0, 1)
    y_pred_binary = np.where(y_pred == '<=50K', 0, 1)

    # Calculate the AUC-ROC score
    auc_roc = roc_auc_score(y_test_binary, y_pred_binary)
    print("AUC-ROC Score:", auc_roc)

    return auc_roc

# %% [markdown]
# ### Objective Function

# %%
# k-anonymity threshold
k = 2

def objective_function(solution, max_suppressed_fraction):
    # Group the data based on the solution
    grouped = df.groupby(solution)
    total_rows_count = 0
    '''
    for group_name, group_data in grouped:
        #group_sum = group_data.sum()
        #print(f"Group Name: {group_name}")
        #print(f"Sum of Rows in Group:\n{group_sum}")
        group_rows_count = len(group_data)
        total_rows_count += group_rows_count

        # Print the total sum of all rows in all groups (just to test that nothing changed)
    print(f"Total Sum of All Rows in All Groups: {total_rows_count}")
    '''

    #print('Grouped rows', grouped)
    #print('SOLUTION', solution)
    #df_tmp = df
    #df_tmp = df[solution]
    additional_columns = ['salary-class']
    df_tmp = df[solution + additional_columns]
    # print('DF TMP INFO', df_tmp)

    # Calculate the percentage of suppressed rows -- utility
    total_rows = len(df)
    suppressed_rows = sum(len(group) for group_name, group in grouped if len(group) < k)
    suppressed_fraction = suppressed_rows / total_rows
    print('SUPPRESSION FRACTION', suppressed_fraction)
    #print('Total Suppressed Rows:', suppressed_rows)
    print('Max Suppressed Fraction:', max_suppressed_fraction)


    suppressed_fraction = round(suppressed_fraction, 2)
    if suppressed_fraction <= max_suppressed_fraction + 1e-6:
    #if testx < testy :

        # Filter the original dataframe to remove suppressed rows
        filtered_df = df_tmp[~df_tmp.index.isin([idx for group_name, group in grouped if len(group) < k for idx in group.index])]
        #print('FILTERED DF INFO', filtered_df.info())

        # Calculate and return classification accuracy as the objective function score
        classification_accuracy = calculate_classification_accuracy(solution, filtered_df, k)
        print('Classification accuracy (AUC-ROC)', classification_accuracy)
        return classification_accuracy

    else: #suppressed_fraction > max_suppressed_fraction:
        # If the constraint is violated, return a penalty (negative infinity)
        print('SUPPRESSION EXCEEDED LIMIT')
        return -float('inf')

# %% [markdown]
# ###Neighbourhood solution

# %%
def get_neighbor_solution(solution):
    neighbor_solution = solution.copy()  # Create a copy of the current solution

    # Define the column sets for swapping
    swap_sets = {
        #'sex': ['sex'],
        'age': ['L1_age', 'L2_age', 'L3_age', 'L4_age', 'L5_age', 'L6_age', 'L7_age'],
        'race': [ 'L1_race', 'L2_race'],
        'education': ['L1_education', 'L2_education', 'L3_education', 'L4_education', 'L5_education'],
        'occupation': [ 'L1_occupation', 'L2_occupation', 'L3_occupation'],
        'workclass':['L1_workclass', 'L2_workclass', 'L3_workclass'],
        'marital_status': ['L1_marital_status', 'L2_marital_status', 'L3_marital_status'],
        'native_country': ['L1_native_country', 'L2_native_country', 'L3_native_country']
    }

    # Iterate over each column set and perform swapping if the current column is from that set
    # Randomly select a set to swap columns
    selected_set = random.choice(list(swap_sets.keys()))
    print('selected set:', selected_set)

    # Randomly shuffle the columns within the selected set
    random.shuffle(swap_sets[selected_set])

    # Replace the corresponding columns in the current solution with the shuffled columns
    for idx, col in enumerate(solution):
        if col in swap_sets[selected_set]:
            neighbor_solution[idx] = random.choice(swap_sets[selected_set])
            print('current solution:', solution)
            print('neighbor solution:', neighbor_solution)

    return neighbor_solution

# %% [markdown]
# ###Simulated Annealing

# %%
df_1 = df

# %%
import math
import random

def simulated_annealing(initial_solution, initial_temperature, cooling_rate, min_temperature, max_iterations_without_improvement, max_suppressed_fraction):
    current_solution = initial_solution  # Store the current solution
    best_solution = initial_solution  # Initialize the best solution as the current solution
    current_temperature = initial_temperature  # Start with the initial temperature
    iterations_without_improvement = 0  # Initialize counter for iterations without improvement
    iteration = 0  # Initialize the iteration counter


    while current_temperature > min_temperature and iterations_without_improvement < max_iterations_without_improvement:
        improved = False

        for _ in range(num_iterations):
            iteration += 1
            print(f"Iteration {iteration}")

            neighbor_solution = get_neighbor_solution(current_solution)

            current_cost = objective_function(current_solution, max_suppressed_fraction)
            print('current_cost:', current_cost)
            neighbor_cost = objective_function(neighbor_solution, max_suppressed_fraction)
            print('neighbor_cost:', neighbor_cost)


            if neighbor_cost >= current_cost:
                current_solution = neighbor_solution
                #if neighbor_cost < objective_function(best_solution, max_suppressed_fraction):
                if neighbor_cost > objective_function(best_solution, max_suppressed_fraction): # and current_cost <= max_suppressed_fraction :
                    best_solution = neighbor_solution
                    print('current best solution:', best_solution)
                    improved = True
            else:
                acceptance_probability = math.exp((current_cost - neighbor_cost) / current_temperature)
                if random.random() < acceptance_probability:
                    current_solution = neighbor_solution
                    improved = True

            print('CURRENT SOLUTION', current_solution)
            if iteration % num_iterations == 0:
                current_temperature *= cooling_rate
                iterations_without_improvement = 0

            if not improved:
                iterations_without_improvement += num_iterations

        current_temperature *= cooling_rate
        iterations_without_improvement += num_iterations

        if improved:
            iterations_without_improvement = 0
        else:
            iterations_without_improvement += num_iterations

    return best_solution


max_suppressed_fraction = 0.10
best_solution = simulated_annealing(initial_solution, initial_temperature, cooling_rate, min_temperature, max_iterations_without_improvement, max_suppressed_fraction)
#max_suppressed_fraction = 0.50  # User-defined maximum suppressed fraction of rows
#auc_roc = objective_function(best_solution, max_suppressed_fraction)  # Calculate the classification accuracy for the best solution



print("Best Solution:", best_solution)
#print("AUC-ROC score:", auc_roc)
# Out:
# Streaming output truncated to the last 5000 lines.
#       dtype='object')
# Number of rows in X: 27598
# Number of rows in y: 27598
# 0:	learn: 0.6499497	total: 19ms	remaining: 929ms
# 20:	learn: 0.3918015	total: 311ms	remaining: 429ms
# 21:	learn: 0.3894999	total: 319ms	remaining: 405ms
# 22:	learn: 0.3869874	total: 341ms	remaining: 401ms
# 23:	learn: 0.3851429	total: 352ms	remaining: 381ms
# 24:	learn: 0.3830675	total: 375ms	remaining: 375ms
# 25:	learn: 0.3809636	total: 398ms	remaining: 367ms
# 26:	learn: 0.3794499	total: 422ms	remaining: 359ms
# 27:	learn: 0.3787516	total: 429ms	remaining: 337ms
# 28:	learn: 0.3776691	total: 441ms	remaining: 320ms
# 29:	learn: 0.3761317	total: 465ms	remaining: 310ms
# 30:	learn: 0.3754077	total: 473ms	remaining: 290ms
# 31:	learn: 0.3742541	total: 502ms	remaining: 283ms
# 32:	learn: 0.3730515	total: 527ms	remaining: 272ms
# 33:	learn: 0.3721592	total: 551ms	remaining: 259ms
# 34:	learn: 0.3711288	total: 575ms	remaining: 246ms
# 35:	learn: 0.3703961	total: 599ms	remaining: 233ms
# 36:	learn: 0.3693875	total: 622ms	remaining: 219ms
# 37:	learn: 0.3690796	total: 631ms	remaining: 199ms
# 38:	learn: 0.3683179	total: 653ms	remaining: 184ms
# 39:	learn: 0.3678589	total: 679ms	remaining: 170ms
# 40:	learn: 0.3674324	total: 694ms	remaining: 152ms
# 41:	learn: 0.3666983	total: 728ms	remaining: 139ms
# 42:	learn: 0.3661031	total: 751ms	remaining: 122ms
# 43:	learn: 0.3655097	total: 774ms	remaining: 106ms
# 44:	learn: 0.3651223	total: 798ms	remaining: 88.6ms
# 45:	learn: 0.3645793	total: 822ms	remaining: 71.4ms
# 46:	learn: 0.3640821	total: 858ms	remaining: 54.8ms
# 47:	learn: 0.3635702	total: 882ms	remaining: 36.8ms
# 48:	learn: 0.3631018	total: 906ms	remaining: 18.5ms
# 49:	learn: 0.3627036	total: 933ms	remaining: 0us
# AUC-ROC Score: 0.7286949238164112
# Classification accuracy (AUC-ROC) 0.7286949238164112
# current_cost: 0.7286949238164112
# SUPPRESSION FRACTION 0.10722100656455143
# Max Suppressed Fraction: 0.1
# SUPPRESSION EXCEEDED LIMIT
# neighbor_cost: -inf
# CURRENT SOLUTION ['sex', 'L4_age', 'L1_race', 'L2_education', 'L3_occupation', 'L2_workclass', 'L2_marital_status', 'L3_native_country']
# Iteration 90
# selected set: marital_status
# current solution: ['sex', 'L4_age', 'L1_race', 'L2_education', 'L3_occupation', 'L2_workclass', 'L2_marital_status', 'L3_native_country']
# neighbor solution: ['sex', 'L4_age', 'L1_race', 'L2_education', 'L3_occupation', 'L2_workclass', 'L2_marital_status', 'L3_native_country']
# SUPPRESSION FRACTION 0.10722100656455143
# Max Suppressed Fraction: 0.1
# SUPPRESSION EXCEEDED LIMIT
# current_cost: -inf
# SUPPRESSION FRACTION 0.10722100656455143
# Max Suppressed Fraction: 0.1
# SUPPRESSION EXCEEDED LIMIT
# neighbor_cost: -inf
# SUPPRESSION FRACTION 0.05563291558915191
# Max Suppressed Fraction: 0.1
# X columns: Index(['sex', 'L5_age', 'L1_race', 'L5_education', 'L1_occupation',
# 46:	learn: 0.3677033	total: 744ms	remaining: 47.5ms
# 47:	learn: 0.3676277	total: 752ms	remaining: 31.3ms
# 48:	learn: 0.3670794	total: 777ms	remaining: 15.8ms
# 49:	learn: 0.3667571	total: 799ms	remaining: 0us
# AUC-ROC Score: 0.7505613934903772
# Classification accuracy (AUC-ROC) 0.7505613934903772
# CURRENT SOLUTION ['sex', 'L4_age', 'L1_race', 'L2_education', 'L3_occupation', 'L2_workclass', 'L2_marital_status', 'L3_native_country']
# Iteration 91
# selected set: race
# current solution: ['sex', 'L4_age', 'L1_race', 'L2_education', 'L3_occupation', 'L2_workclass', 'L2_marital_status', 'L3_native_country']
# neighbor solution: ['sex', 'L4_age', 'L1_race', 'L2_education', 'L3_occupation', 'L2_workclass', 'L2_marital_status', 'L3_native_country']
# SUPPRESSION FRACTION 0.10722100656455143
# Max Suppressed Fraction: 0.1
# SUPPRESSION EXCEEDED LIMIT
# current_cost: -inf
# SUPPRESSION FRACTION 0.10722100656455143
# Max Suppressed Fraction: 0.1
# SUPPRESSION EXCEEDED LIMIT
# neighbor_cost: -inf
# SUPPRESSION FRACTION 0.05563291558915191
# Max Suppressed Fraction: 0.1
# X columns: Index(['sex', 'L5_age', 'L1_race', 'L5_education', 'L1_occupation',
#        'L1_workclass', 'L1_marital_status', 'L1_native_country'],
#       dtype='object')
# Number of rows in X: 28484
# Number of rows in y: 28484
# 0:	learn: 0.6502159	total: 7.53ms	remaining: 369ms
# 1:	learn: 0.6151586	total: 15ms	remaining: 361ms
# 2:	learn: 0.5861700	total: 21ms	remaining: 329ms
# 3:	learn: 0.5616269	total: 28.1ms	remaining: 323ms
# 4:	learn: 0.5409746	total: 36.4ms	remaining: 328ms
# 5:	learn: 0.5234945	total: 43.6ms	remaining: 320ms
# 6:	learn: 0.5088748	total: 50ms	remaining: 307ms
# 7:	learn: 0.4961608	total: 57.1ms	remaining: 300ms
# 8:	learn: 0.4855181	total: 63.5ms	remaining: 289ms
# 9:	learn: 0.4764109	total: 69.6ms	remaining: 278ms
# 10:	learn: 0.4683347	total: 76.5ms	remaining: 271ms
# 11:	learn: 0.4616326	total: 82.5ms	remaining: 261ms
# 12:	learn: 0.4556157	total: 89.4ms	remaining: 254ms
# 13:	learn: 0.4464082	total: 100ms	remaining: 257ms
# 14:	learn: 0.4384423	total: 118ms	remaining: 275ms
# 15:	learn: 0.4316749	total: 136ms	remaining: 289ms
# 16:	learn: 0.4257750	total: 148ms	remaining: 287ms
# 17:	learn: 0.4210601	total: 158ms	remaining: 281ms
# 18:	learn: 0.4166808	total: 179ms	remaining: 291ms
# 19:	learn: 0.4129434	total: 200ms	remaining: 299ms
# 20:	learn: 0.4098243	total: 230ms	remaining: 318ms
# 21:	learn: 0.4047634	total: 252ms	remaining: 321ms
# 22:	learn: 0.4002590	total: 273ms	remaining: 321ms
# 23:	learn: 0.3963512	total: 291ms	remaining: 316ms
# 24:	learn: 0.3930602	total: 312ms	remaining: 312ms
# 25:	learn: 0.3900842	total: 330ms	remaining: 305ms
# 26:	learn: 0.3873590	total: 351ms	remaining: 299ms
# 27:	learn: 0.3849591	total: 372ms	remaining: 292ms
# 28:	learn: 0.3830745	total: 393ms	remaining: 284ms
# 29:	learn: 0.3813836	total: 414ms	remaining: 276ms
# 30:	learn: 0.3796687	total: 440ms	remaining: 270ms
# 31:	learn: 0.3779561	total: 466ms	remaining: 262ms
# 32:	learn: 0.3768287	total: 475ms	remaining: 245ms
# 33:	learn: 0.3755723	total: 496ms	remaining: 234ms
# 34:	learn: 0.3743619	total: 518ms	remaining: 222ms
# 35:	learn: 0.3733830	total: 532ms	remaining: 207ms
# 36:	learn: 0.3726891	total: 542ms	remaining: 190ms
# 37:	learn: 0.3717406	total: 563ms	remaining: 178ms
# 38:	learn: 0.3710608	total: 584ms	remaining: 165ms
# 39:	learn: 0.3704768	total: 605ms	remaining: 151ms
# 40:	learn: 0.3698890	total: 626ms	remaining: 138ms
# 41:	learn: 0.3696425	total: 634ms	remaining: 121ms
# 42:	learn: 0.3692742	total: 649ms	remaining: 106ms
# 43:	learn: 0.3688219	total: 672ms	remaining: 91.7ms
# 44:	learn: 0.3683933	total: 700ms	remaining: 77.8ms
# 45:	learn: 0.3678887	total: 732ms	remaining: 63.7ms
# 46:	learn: 0.3677033	total: 743ms	remaining: 47.4ms
# 47:	learn: 0.3676277	total: 751ms	remaining: 31.3ms
# 48:	learn: 0.3670794	total: 773ms	remaining: 15.8ms
# 49:	learn: 0.3667571	total: 795ms	remaining: 0us
# AUC-ROC Score: 0.7505613934903772
# Classification accuracy (AUC-ROC) 0.7505613934903772
# CURRENT SOLUTION ['sex', 'L4_age', 'L1_race', 'L2_education', 'L3_occupation', 'L2_workclass', 'L2_marital_status', 'L3_native_country']
# Iteration 92
# selected set: education
# current solution: ['sex', 'L4_age', 'L1_race', 'L2_education', 'L3_occupation', 'L2_workclass', 'L2_marital_status', 'L3_native_country']
# neighbor solution: ['sex', 'L4_age', 'L1_race', 'L5_education', 'L3_occupation', 'L2_workclass', 'L2_marital_status', 'L3_native_country']
# SUPPRESSION FRACTION 0.10722100656455143
# Max Suppressed Fraction: 0.1
# SUPPRESSION EXCEEDED LIMIT
# current_cost: -inf
# SUPPRESSION FRACTION 0.1757177905974405
# Max Suppressed Fraction: 0.1
# SUPPRESSION EXCEEDED LIMIT
# neighbor_cost: -inf
# SUPPRESSION FRACTION 0.05563291558915191
# Max Suppressed Fraction: 0.1
# X columns: Index(['sex', 'L5_age', 'L1_race', 'L5_education', 'L1_occupation',
#        'L1_workclass', 'L1_marital_status', 'L1_native_country'],
#       dtype='object')
# Number of rows in X: 28484
# Number of rows in y: 28484
# 0:	learn: 0.6502159	total: 7.64ms	remaining: 374ms
# 1:	learn: 0.6151586	total: 15.6ms	remaining: 374ms
# 2:	learn: 0.5861700	total: 22.1ms	remaining: 347ms
# 3:	learn: 0.5616269	total: 38.5ms	remaining: 443ms
# 4:	learn: 0.5409746	total: 55.5ms	remaining: 500ms
# 5:	learn: 0.5234945	total: 63.3ms	remaining: 464ms
# 35:	learn: 0.3733830	total: 559ms	remaining: 217ms
# 36:	learn: 0.3726891	total: 568ms	remaining: 200ms
# 37:	learn: 0.3717406	total: 590ms	remaining: 186ms
# 38:	learn: 0.3710608	total: 612ms	remaining: 173ms
# 39:	learn: 0.3704768	total: 640ms	remaining: 160ms
# 40:	learn: 0.3698890	total: 668ms	remaining: 147ms
# 41:	learn: 0.3696425	total: 676ms	remaining: 129ms
# 42:	learn: 0.3692742	total: 687ms	remaining: 112ms
# 43:	learn: 0.3688219	total: 708ms	remaining: 96.6ms
# 44:	learn: 0.3683933	total: 731ms	remaining: 81.3ms
# 45:	learn: 0.3678887	total: 753ms	remaining: 65.4ms
# 46:	learn: 0.3677033	total: 763ms	remaining: 48.7ms
# 47:	learn: 0.3676277	total: 770ms	remaining: 32.1ms
# 48:	learn: 0.3670794	total: 791ms	remaining: 16.2ms
# 49:	learn: 0.3667571	total: 813ms	remaining: 0us
# AUC-ROC Score: 0.7505613934903772
# Classification accuracy (AUC-ROC) 0.7505613934903772
# CURRENT SOLUTION ['sex', 'L4_age', 'L1_race', 'L5_education', 'L3_occupation', 'L2_workclass', 'L2_marital_status', 'L3_native_country']
# Iteration 94
# selected set: workclass
# current solution: ['sex', 'L4_age', 'L1_race', 'L5_education', 'L3_occupation', 'L2_workclass', 'L2_marital_status', 'L3_native_country']
# neighbor solution: ['sex', 'L4_age', 'L1_race', 'L5_education', 'L3_occupation', 'L1_workclass', 'L2_marital_status', 'L3_native_country']
# SUPPRESSION FRACTION 0.1757177905974405
# Max Suppressed Fraction: 0.1
# SUPPRESSION EXCEEDED LIMIT
# current_cost: -inf
# SUPPRESSION FRACTION 0.15489689012664942
# Max Suppressed Fraction: 0.1
# SUPPRESSION EXCEEDED LIMIT
# neighbor_cost: -inf
# SUPPRESSION FRACTION 0.05563291558915191
# Max Suppressed Fraction: 0.1
# X columns: Index(['sex', 'L5_age', 'L1_race', 'L5_education', 'L1_occupation',
#        'L1_workclass', 'L1_marital_status', 'L1_native_country'],
#       dtype='object')
# Number of rows in X: 28484
# Number of rows in y: 28484
# 0:	learn: 0.6502159	total: 15.8ms	remaining: 772ms
# 1:	learn: 0.6151586	total: 27.9ms	remaining: 669ms
# 2:	learn: 0.5861700	total: 40.9ms	remaining: 641ms
# 3:	learn: 0.5616269	total: 50.2ms	remaining: 578ms
# 4:	learn: 0.5409746	total: 68.5ms	remaining: 616ms
# 5:	learn: 0.5234945	total: 78.8ms	remaining: 578ms
# 6:	learn: 0.5088748	total: 88.6ms	remaining: 545ms
# 7:	learn: 0.4961608	total: 97.7ms	remaining: 513ms
# 8:	learn: 0.4855181	total: 110ms	remaining: 502ms
# 9:	learn: 0.4764109	total: 123ms	remaining: 492ms
# 10:	learn: 0.4683347	total: 133ms	remaining: 471ms
# 11:	learn: 0.4616326	total: 141ms	remaining: 445ms
# 12:	learn: 0.4556157	total: 151ms	remaining: 429ms
# 13:	learn: 0.4464082	total: 171ms	remaining: 439ms
# 14:	learn: 0.4384423	total: 202ms	remaining: 472ms
# 44:	learn: 0.3683933	total: 722ms	remaining: 80.2ms
# 45:	learn: 0.3678887	total: 743ms	remaining: 64.6ms
# 46:	learn: 0.3677033	total: 754ms	remaining: 48.1ms
# 47:	learn: 0.3676277	total: 761ms	remaining: 31.7ms
# 48:	learn: 0.3670794	total: 783ms	remaining: 16ms
# 49:	learn: 0.3667571	total: 805ms	remaining: 0us
# AUC-ROC Score: 0.7505613934903772
# Classification accuracy (AUC-ROC) 0.7505613934903772
# CURRENT SOLUTION ['sex', 'L4_age', 'L1_race', 'L5_education', 'L3_occupation', 'L1_workclass', 'L2_marital_status', 'L1_native_country']
# Iteration 96
# selected set: occupation
# current solution: ['sex', 'L4_age', 'L1_race', 'L5_education', 'L3_occupation', 'L1_workclass', 'L2_marital_status', 'L1_native_country']
# neighbor solution: ['sex', 'L4_age', 'L1_race', 'L5_education', 'L1_occupation', 'L1_workclass', 'L2_marital_status', 'L1_native_country']
# SUPPRESSION FRACTION 0.11879185730389231
# Max Suppressed Fraction: 0.1
# SUPPRESSION EXCEEDED LIMIT
# current_cost: -inf
# SUPPRESSION FRACTION 0.04406206484981102
# Max Suppressed Fraction: 0.1
# X columns: Index(['sex', 'L4_age', 'L1_race', 'L5_education', 'L1_occupation',
#        'L1_workclass', 'L2_marital_status', 'L1_native_country'],
#       dtype='object')
# Number of rows in X: 28833
# Number of rows in y: 28833
# 0:	learn: 0.6492051	total: 14.3ms	remaining: 699ms
# 1:	learn: 0.6133260	total: 31.9ms	remaining: 765ms
# 2:	learn: 0.5836619	total: 43ms	remaining: 673ms
# 3:	learn: 0.5585986	total: 55.2ms	remaining: 635ms
# 4:	learn: 0.5374946	total: 64.2ms	remaining: 577ms
# 5:	learn: 0.5198657	total: 72ms	remaining: 528ms
# 6:	learn: 0.5046305	total: 80.9ms	remaining: 497ms
# 7:	learn: 0.4913170	total: 91.7ms	remaining: 481ms
# 8:	learn: 0.4798996	total: 101ms	remaining: 458ms
# 9:	learn: 0.4703339	total: 111ms	remaining: 443ms
# ...
# CURRENT SOLUTION ['sex', 'L1_age', 'L2_race', 'L2_education', 'L1_occupation', 'L2_workclass', 'L1_marital_status', 'L3_native_country']
# Iteration 119
# selected set: native_country
# current solution: ['sex', 'L1_age', 'L2_race', 'L2_education', 'L1_occupation', 'L2_workclass', 'L1_marital_status', 'L3_native_country']
# neighbor solution: ['sex', 'L1_age', 'L2_race', 'L2_education', 'L1_occupation', 'L2_workclass', 'L1_marital_status', 'L2_native_country']
# SUPPRESSION FRACTION 0.021483986473045554
# Max Suppressed Fraction: 0.1
# X columns: Index(['sex', 'L1_age', 'L2_race', 'L2_education', 'L1_occupation',
#        'L2_workclass', 'L1_marital_status', 'L3_native_country'],
#       dtype='object')
# Number of rows in X: 29514
# Number of rows in y: 29514
# 0:	learn: 0.6497653	total: 6.96ms	remaining: 341ms
# 1:	learn: 0.6143401	total: 13.8ms	remaining: 330ms
# 2:	learn: 0.5821676	total: 21.9ms	remaining: 344ms
# 3:	learn: 0.5553694	total: 29.6ms	remaining: 341ms
# L3_age                                        [36, 54)
# L4_age                                        [36, 45)
# L5_age                                        [36, 40)
# L6_age                                        [38, 40)
# L7_age                                            39.0
# L1_education                          Higher Education
# L2_education                        Advanced Education
# L3_education                        Advanced Education
# L4_education                        Advanced Education
# L5_education                                 Bachelors
# L1_occupation      Professional or Administrative Role
# L2_occupation               Sales and Customer Service
# L3_occupation                             Adm-clerical
# L1_workclass                                Government
# L2_workclass                                Government
# L3_workclass                                Government
# L1_marital_status                          Not married
# L2_marital_status                               Single
# L3_marital_status                        Never-married
# L1_native_country                        North America
# L2_native_country                        North America
# L3_native_country                        United-States
# L1_race                                          White
# L2_race                                          White
# salary-class                                     <=50K
#
#                                                      1  \
# sex                                               Male
# L1_age                                      [17, 91.0)
# L2_age                                        [17, 54)
# L3_age                                        [36, 54)
# L4_age                                        [45, 54)
# L5_age                                        [49, 54)
# L6_age                                        [49, 52)
# L7_age                                            50.0
# L1_education                          Higher Education
# L2_education                        Advanced Education
# L3_education                        Advanced Education
# L4_education                        Advanced Education
# L5_education                                 Bachelors
# L1_occupation      Professional or Administrative Role
# L2_occupation          Management or Professional Role
# L3_occupation                          Exec-managerial
# L1_workclass                          Private or other
# L2_workclass                             Self-employed
# L3_workclass                             Self-employed
# L1_marital_status                              Married
# L2_marital_status                              Married
# L3_marital_status                   Married-civ-spouse
# L1_native_country                        North America
# L2_native_country                        North America
# L3_native_country                        United-States
# L1_race                                          White
# L2_race                                          White
# salary-class                                     <=50K
#
#                                                  2  \
# sex                                           Male
# L1_age                                  [17, 91.0)
# L2_age                                    [17, 54)
# L3_age                                    [36, 54)
# L4_age                                    [36, 45)
# L5_age                                    [36, 40)
# L6_age                                    [38, 40)
# L7_age                                        38.0
# L1_education                      School Education
# L2_education                      School Education
# L3_education                 High School Education
# L4_education                 High School Education
# L5_education                               HS-grad
# L1_occupation             Manual and Skilled Labor
# L2_occupation      Skilled Labor and Craftsmanship
# L3_occupation                    Handlers-cleaners
# L1_workclass                      Private or other
# L2_workclass                               Private
# L3_workclass                               Private
# L1_marital_status                      Not married
# L2_marital_status                    Spouse absent
# L3_marital_status                         Divorced
# L1_native_country                    North America
# L2_native_country                    North America
# L3_native_country                    United-States
# L1_race                                      White
# L2_race                                      White
# salary-class                                 <=50K
#
#                                                  3  \
# sex                                           Male
# L1_age                                  [17, 91.0)
# L2_age                                    [17, 54)
# L3_age                                    [36, 54)
# L4_age                                    [45, 54)
# L5_age                                    [49, 54)
# L6_age                                    [52, 54)
# L7_age                                        53.0
# L1_education                      School Education
# L2_education                      School Education
# L3_education                 High School Education
# L4_education                 High School Education
# L5_education                                  11th
# L1_occupation             Manual and Skilled Labor
# L2_occupation      Skilled Labor and Craftsmanship
# L3_occupation                    Handlers-cleaners
# L1_workclass                      Private or other
# L2_workclass                               Private
# L3_workclass                               Private
# L1_marital_status                          Married
# L2_marital_status                          Married
# L3_marital_status               Married-civ-spouse
# L1_native_country                    North America
# L2_native_country                    North America
# L3_native_country                    United-States
# L1_race                                      Black
# L2_race                                      Black
# salary-class                                 <=50K
#
#                                                      4  \
# sex                                             Female
# L1_age                                      [17, 91.0)
# L2_age                                        [17, 54)
# L3_age                                        [17, 36)
# L4_age                                        [27, 36)
# L5_age                                        [27, 31)
# L6_age                                        [27, 29)
# L7_age                                            28.0
# L1_education                          Higher Education
# L2_education                        Advanced Education
# L3_education                        Advanced Education
# L4_education                        Advanced Education
# L5_education                                 Bachelors
# L1_occupation      Professional or Administrative Role
# L2_occupation          Management or Professional Role
# L3_occupation                           Prof-specialty
# L1_workclass                          Private or other
# L2_workclass                                   Private
# L3_workclass                                   Private
# L1_marital_status                              Married
# L2_marital_status                              Married
# L3_marital_status                   Married-civ-spouse
# L1_native_country                        North America
# L2_native_country    Central America and the Caribbean
# L3_native_country                                 Cuba
# L1_race                                          Black
# L2_race                                          Black
# salary-class                                     <=50K
#
#                                                      5  \
# sex                                             Female
# L1_age                                      [17, 91.0)
# L2_age                                        [17, 54)
# L3_age                                        [36, 54)
# L4_age                                        [36, 45)
# L5_age                                        [36, 40)
# L6_age                                        [36, 38)
# L7_age                                            37.0
# L1_education                          Higher Education
# L2_education                        Advanced Education
# L3_education                        Advanced Education
# L4_education                        Advanced Education
# L5_education                                   Masters
# L1_occupation      Professional or Administrative Role
# L2_occupation          Management or Professional Role
# L3_occupation                          Exec-managerial
# L1_workclass                          Private or other
# L2_workclass                                   Private
# L3_workclass                                   Private
# L1_marital_status                              Married
# L2_marital_status                              Married
# L3_marital_status                   Married-civ-spouse
# L1_native_country                        North America
# L2_native_country                        North America
# L3_native_country                        United-States
# L1_race                                          White
# L2_race                                          White
# salary-class                                     <=50K
#
#                                                     6  \
# sex                                            Female
# L1_age                                     [17, 91.0)
# L2_age                                       [17, 54)
# L3_age                                       [36, 54)
# L4_age                                       [45, 54)
# L5_age                                       [49, 54)
# L6_age                                       [49, 52)
# L7_age                                           49.0
# L1_education                         School Education
# L2_education                         School Education
# L3_education       Middle/Elementary School Education
# L4_education                  Middle School Education
# L5_education                                      9th
# L1_occupation                Manual and Skilled Labor
# L2_occupation             Service and Household Roles
# L3_occupation                           Other-service
# L1_workclass                         Private or other
# L2_workclass                                  Private
# L3_workclass                                  Private
# L1_marital_status                             Married
# L2_marital_status                       Spouse absent
# L3_marital_status               Married-spouse-absent
# L1_native_country                       North America
# L2_native_country   Central America and the Caribbean
# L3_native_country                             Jamaica
# L1_race                                         Black
# L2_race                                         Black
# salary-class                                    <=50K
#
#                                                      7  \
# sex                                               Male
# L1_age                                      [17, 91.0)
# L2_age                                        [17, 54)
# L3_age                                        [36, 54)
# L4_age                                        [45, 54)
# L5_age                                        [49, 54)
# L6_age                                        [52, 54)
# L7_age                                            52.0
# L1_education                          School Education
# L2_education                          School Education
# L3_education                     High School Education
# L4_education                     High School Education
# L5_education                                   HS-grad
# L1_occupation      Professional or Administrative Role
# L2_occupation          Management or Professional Role
# L3_occupation                          Exec-managerial
# L1_workclass                          Private or other
# L2_workclass                             Self-employed
# L3_workclass                             Self-employed
# L1_marital_status                              Married
# L2_marital_status                              Married
# L3_marital_status                   Married-civ-spouse
# L1_native_country                        North America
# L2_native_country                        North America
# L3_native_country                        United-States
# L1_race                                          White
# L2_race                                          White
# salary-class                                      >50K
#
#                                                      8  \
# sex                                             Female
# L1_age                                      [17, 91.0)
# L2_age                                        [17, 54)
# L3_age                                        [17, 36)
# L4_age                                        [27, 36)
# L5_age                                        [31, 36)
# L6_age                                        [31, 33)
# L7_age                                            31.0
# L1_education                          Higher Education
# L2_education                        Advanced Education
# L3_education                        Advanced Education
# L4_education                        Advanced Education
# L5_education                                   Masters
# L1_occupation      Professional or Administrative Role
# L2_occupation          Management or Professional Role
# L3_occupation                           Prof-specialty
# L1_workclass                          Private or other
# L2_workclass                                   Private
# L3_workclass                                   Private
# L1_marital_status                          Not married
# L2_marital_status                               Single
# L3_marital_status                        Never-married
# L1_native_country                        North America
# L2_native_country                        North America
# L3_native_country                        United-States
# L1_race                                          White
# L2_race                                          White
# salary-class                                      >50K
#
#                                                      9
# sex                                               Male
# L1_age                                      [17, 91.0)
# L2_age                                        [17, 54)
# L3_age                                        [36, 54)
# L4_age                                        [36, 45)
# L5_age                                        [40, 45)
# L6_age                                        [40, 43)
# L7_age                                            42.0
# L1_education                          Higher Education
# L2_education                        Advanced Education
# L3_education                        Advanced Education
# L4_education                        Advanced Education
# L5_education                                 Bachelors
# L1_occupation      Professional or Administrative Role
# L2_occupation          Management or Professional Role
# L3_occupation                          Exec-managerial
# L1_workclass                          Private or other
# L2_workclass                                   Private
# L3_workclass                                   Private
# L1_marital_status                              Married
# L2_marital_status                              Married
# L3_marital_status                   Married-civ-spouse
# L1_native_country                        North America
# L2_native_country                        North America
# L3_native_country                        United-States
# L1_race                                          White
# L2_race                                          White
# salary-class                                      >50K

# %%
'''
# Define the privacy parameter
k = 7

#For testing purposes

test_solution = ['sex', 'L4_age', 'L1_race', 'L1_education', 'L3_occupation', 'L2_workclass', 'L1_marital_status', 'L3_native_country']

#test_solution = best_solution

df_k = df

# Group the dataset by the quasi-identifiers and suppress the groups with less than k rows
grouped = df_k.groupby(test_solution)
suppressed_indices = []
for group_name, group in grouped:
    if len(group) < k:
        suppressed_indices.extend(group.index)
df_k = df_k.drop(suppressed_indices)
#df_k.info()
# Restore the original index
df_index = df_k.index
df_k = df_k.reset_index(drop=True)

counter = 0
for index in suppressed_indices:
    counter = counter + 1
    #print(df_k.loc[index])
    #print("------------")
print('sum of supressed records:', counter)
total_rows = len(df)
suppressed_rows = counter
suppressed_fraction = suppressed_rows / total_rows
print('SUPPRESSION FRACTION', suppressed_fraction)
'''
# Out:
# '\n# Define the privacy parameter\nk = 7\n\n#For testing purposes\n\ntest_solution = [\'sex\', \'L4_age\', \'L1_race\', \'L1_education\', \'L3_occupation\', \'L2_workclass\', \'L1_marital_status\', \'L3_native_country\']\n\n#test_solution = best_solution\n\ndf_k = df\n\n# Group the dataset by the quasi-identifiers and suppress the groups with less than k rows\ngrouped = df_k.groupby(test_solution)\nsuppressed_indices = []\nfor group_name, group in grouped:\n    if len(group) < k:\n        suppressed_indices.extend(group.index)\ndf_k = df_k.drop(suppressed_indices)\n#df_k.info()\n# Restore the original index\ndf_index = df_k.index\ndf_k = df_k.reset_index(drop=True)\n\ncounter = 0\nfor index in suppressed_indices:\n    counter = counter + 1\n    #print(df_k.loc[index])\n    #print("------------")\nprint(\'sum of supressed records:\', counter)\ntotal_rows = len(df)\nsuppressed_rows = counter\nsuppressed_fraction = suppressed_rows / total_rows\nprint(\'SUPPRESSION FRACTION\', suppressed_fraction)\n'

# %% [markdown]
# ### Run the classification model again but with 500 iterations to find the best classification accuracy the attribute set can achieve

# %%
#df.columns()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score, classification_report

#selected_columns = best_solution

# k for baseline tests



df_k = df
#org
additional_columns = ['salary-class']
#features = ['sex', 'L6_age', 'L2_race', 'L4_education', 'L1_occupation', 'L1_workclass', 'L3_marital_status', 'L1_native_country']
features = best_solution

# Group the dataset by the quasi-identifiers and suppress the groups with less than k rows
grouped = df_k.groupby(features)
suppressed_indices = []
for group_name, group in grouped:
    if len(group) < k:
        suppressed_indices.extend(group.index)
df_k = df_k.drop(suppressed_indices)
df_k.info()
# Restore the original index
df_index = df_k.index
df_k = df_k.reset_index(drop=True)

featurez_matrix = df_k[features + additional_columns]

# Set a random seed for reproducibility
random_seed = 23 #23  # You can use any integer value as the seed #bseline tested with 23->752, 26->760, 27->0.751, 28->744
np.random.seed(random_seed)

# Prepare the feature matrix (X) and target variable (y)
X = featurez_matrix.drop('salary-class', axis=1)
y = featurez_matrix['salary-class']


counter = 0
for index in suppressed_indices:
    counter = counter + 1
    #print(df_k.loc[index])
    #print("------------")
print('sum of supressed records:', counter)
total_rows = len(df)
suppressed_rows = counter
suppressed_fraction = suppressed_rows / total_rows
print('SUPPRESSION FRACTION', suppressed_fraction)
print('K-value:', k)
print('anon df columns:', df_k.columns)


# Convert categorical features to strings
categorical_features_indices = X.select_dtypes(include=['object']).columns
#X[categorical_features_indices] = X[categorical_features_indices].astype(str)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed)



# Initialize the CatBoostClassifier
catboost_model = CatBoostClassifier(iterations=600, depth=7, learning_rate=0.05, loss_function='Logloss', cat_features=list(categorical_features_indices))

# Train the model on the training data
catboost_model.fit(X_train, y_train, cat_features=list(categorical_features_indices))  # Convert to list here

# Predict on the testing data
y_pred = catboost_model.predict(X_test)
# Convert the predicted labels to string type
y_pred = y_pred.astype(str)


# Evaluate the model's performance
classification_metrics = classification_report(y_test, y_pred, digits=3)
print(classification_metrics)


# Assuming you have y_test and y_pred with labels '<=50K' and '>50K'
# Convert labels to binary values (0 and 1)
y_test_binary = np.where(y_test == '<=50K', 0, 1)
y_pred_binary = np.where(y_pred == '<=50K', 0, 1)

# Calculate the AUC-ROC score
auc_roc = roc_auc_score(y_test_binary, y_pred_binary)
print("AUC-ROC Score: {:.3f}".format(auc_roc))


counter = 0
for index in suppressed_indices:
    counter = counter + 1
    #print(df_k.loc[index])
    #print("------------")
print('sum of supressed records:', counter)
total_rows = len(df)
suppressed_rows = counter
suppressed_fraction = suppressed_rows / total_rows
print('SUPPRESSION FRACTION', suppressed_fraction)
print('K-value:', k)
print('anon df columns:', X.columns)
print('best solution', best_solution)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28484 entries, 0 to 30161
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sex                28484 non-null  object
#  1   L1_age             28484 non-null  object
#  2   L2_age             28484 non-null  object
#  3   L3_age             28484 non-null  object
#  4   L4_age             28484 non-null  object
#  5   L5_age             28484 non-null  object
#  6   L6_age             28484 non-null  object
#  7   L7_age             28484 non-null  object
#  8   L1_education       28484 non-null  object
#  9   L2_education       28484 non-null  object
#  10  L3_education       28484 non-null  object
#  11  L4_education       28484 non-null  object
#  12  L5_education       28484 non-null  object
#  13  L1_occupation      28484 non-null  object
#  14  L2_occupation      28484 non-null  object
#  15  L3_occupation      28484 non-null  object
#  16  L1_workclass       28484 non-null  object
#  17  L2_workclass       28484 non-null  object
#  18  L3_workclass       28484 non-null  object
#  19  L1_marital_status  28484 non-null  object
#  20  L2_marital_status  28484 non-null  object
#  21  L3_marital_status  28484 non-null  object
#  22  L1_native_country  28484 non-null  object
#  23  L2_native_country  28484 non-null  object
#  24  L3_native_country  28484 non-null  object
#  25  L1_race            28484 non-null  object
#  26  L2_race            28484 non-null  object
#  27  salary-class       28484 non-null  object
# dtypes: object(28)
# memory usage: 6.3+ MB
# sum of supressed records: 1678
# SUPPRESSION FRACTION 0.05563291558915191
# K-value: 2
# anon df columns: Index(['sex', 'L1_age', 'L2_age', 'L3_age', 'L4_age', 'L5_age', 'L6_age',
#        'L7_age', 'L1_education', 'L2_education', 'L3_education',
#        'L4_education', 'L5_education', 'L1_occupation', 'L2_occupation',
#        'L3_occupation', 'L1_workclass', 'L2_workclass', 'L3_workclass',
#        'L1_marital_status', 'L2_marital_status', 'L3_marital_status',
#        'L1_native_country', 'L2_native_country', 'L3_native_country',
#        'L1_race', 'L2_race', 'salary-class'],
#       dtype='object')
# 0:	learn: 0.6574288	total: 77.8ms	remaining: 46.6s
# 1:	learn: 0.6277586	total: 132ms	remaining: 39.5s
# 2:	learn: 0.6019441	total: 172ms	remaining: 34.2s
# 3:	learn: 0.5795098	total: 194ms	remaining: 28.9s
# 4:	learn: 0.5584303	total: 286ms	remaining: 34s
# 5:	learn: 0.5412487	total: 354ms	remaining: 35s
# 6:	learn: 0.5176063	total: 453ms	remaining: 38.3s
# 7:	learn: 0.4993793	total: 542ms	remaining: 40.1s
# 8:	learn: 0.4841023	total: 613ms	remaining: 40.3s
# 9:	learn: 0.4701863	total: 695ms	remaining: 41s
# 10:	learn: 0.4584289	total: 766ms	remaining: 41s
# 11:	learn: 0.4488958	total: 831ms	remaining: 40.7s
# 12:	learn: 0.4395492	total: 881ms	remaining: 39.8s
# 13:	learn: 0.4328802	total: 919ms	remaining: 38.5s
# 14:	learn: 0.4265197	total: 979ms	remaining: 38.2s
# 15:	learn: 0.4202045	total: 1.02s	remaining: 37.3s
# 16:	learn: 0.4152557	total: 1.09s	remaining: 37.4s
# 17:	learn: 0.4103095	total: 1.15s	remaining: 37.3s
# 581:	learn: 0.3397164	total: 20.3s	remaining: 627ms
# 582:	learn: 0.3396687	total: 20.3s	remaining: 592ms
# 583:	learn: 0.3395698	total: 20.3s	remaining: 557ms
# 584:	learn: 0.3395168	total: 20.4s	remaining: 522ms
# 585:	learn: 0.3395130	total: 20.4s	remaining: 488ms
# 586:	learn: 0.3394292	total: 20.4s	remaining: 453ms
# 587:	learn: 0.3394122	total: 20.5s	remaining: 418ms
# 588:	learn: 0.3394057	total: 20.5s	remaining: 383ms
# 589:	learn: 0.3393596	total: 20.5s	remaining: 348ms
# 590:	learn: 0.3393262	total: 20.6s	remaining: 313ms
# 591:	learn: 0.3392843	total: 20.6s	remaining: 278ms
# 592:	learn: 0.3392408	total: 20.6s	remaining: 244ms
# 593:	learn: 0.3392313	total: 20.7s	remaining: 209ms
# 594:	learn: 0.3391512	total: 20.7s	remaining: 174ms
# 595:	learn: 0.3391433	total: 20.7s	remaining: 139ms
# 596:	learn: 0.3391043	total: 20.8s	remaining: 104ms
# 597:	learn: 0.3390550	total: 20.8s	remaining: 69.5ms
# 598:	learn: 0.3390383	total: 20.8s	remaining: 34.8ms
# 599:	learn: 0.3390087	total: 20.9s	remaining: 0us
#               precision    recall  f1-score   support
#
#        <=50K      0.869     0.915     0.892      4282
#         >50K      0.695     0.582     0.634      1415
#
#     accuracy                          0.833      5697
#    macro avg      0.782     0.749     0.763      5697
# weighted avg      0.826     0.833     0.828      5697
#
# AUC-ROC Score: 0.749
# sum of supressed records: 1678
# SUPPRESSION FRACTION 0.05563291558915191
# K-value: 2
# anon df columns: Index(['sex', 'L5_age', 'L1_race', 'L5_education', 'L1_occupation',
#        'L1_workclass', 'L1_marital_status', 'L1_native_country'],
#       dtype='object')
# best solution ['sex', 'L5_age', 'L1_race', 'L5_education', 'L1_occupation', 'L1_workclass', 'L1_marital_status', 'L1_native_country']

# %%
print(k)
# Out:
# 2

# %%
X.columns
# Out:
# Index(['sex', 'L6_age', 'L2_race', 'L3_education', 'L1_occupation',
#        'L3_workclass', 'L2_marital_status', 'L2_native_country'],
#       dtype='object')

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27332 entries, 0 to 27331
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sex                27332 non-null  object
#  1   L6_age             27332 non-null  object
#  2   L2_race            27332 non-null  object
#  3   L3_education       27332 non-null  object
#  4   L1_occupation      27332 non-null  object
#  5   L3_workclass       27332 non-null  object
#  6   L2_marital_status  27332 non-null  object
#  7   L2_native_country  27332 non-null  object
# dtypes: object(8)
# memory usage: 1.7+ MB

# %%
df[best_solution].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30162 entries, 0 to 30161
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sex                30162 non-null  object
#  1   L6_age             30162 non-null  object
#  2   L2_race            30162 non-null  object
#  3   L3_education       30162 non-null  object
#  4   L1_occupation      30162 non-null  object
#  5   L3_workclass       30162 non-null  object
#  6   L2_marital_status  30162 non-null  object
#  7   L2_native_country  30162 non-null  object
# dtypes: object(8)
# memory usage: 1.8+ MB

# %% [markdown]
# Run this again to check if the number of supressed rows outputted by the simulated annealing is actually the optimal one. The snipped takes the set of features returned the the SA algorithm and performs k-anonymity on them.
